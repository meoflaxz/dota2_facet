# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.dotabuff.com/heroes?show=facets&view=played&mode=turbo&date=7d'

def scrape_all_heroes(url):
    # Add headers to mimic a real browser request
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    # Send a GET request to the URL
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        heroes = soup.find_all('tr', class_="tw-border-b tw-transition-colors hover:tw-bg-muted/50 data-[state=selected]:tw-bg-muted")
        # href = heroes.find("a")
        for hero in heroes:
            facets = hero.find("div", {"class":"tw-text-xs tw-text-secondary"})
            a_tag = hero.find('a', class_='tw-flex tw-items-center tw-gap-3')
            numbers = hero.find_all('div', class_='tw-flex tw-w-full tw-flex-col tw-items-start tw-gap-1', limit=5)

            if a_tag:
                href = a_tag['href']

                match = re.search(r'/heroes/(.*)', href)
                if match:
                    hero_name = match.group(1)
                    facet = facets.text
                    
                    if len(numbers) == 5:
                        win_rate = numbers[2]
                        no_matches = numbers[0]
                        kda = numbers[4]
                        print(f'{hero_name}, {facet}, {win_rate.text}, {no_matches.text}, {kda.text}')
            
    else:
        print(f'Failed to retrieve the webpage. Status code: {response.status_code}')

scrape_all_heroes(url)
# Out:
# pudge, Fresh Meat, 54.18%, 1,243,520, 3.02
# shadow-fiend, Shadowmire, 47.18%, 1,004,785, 2.79
# ogre-magi, Fat Chance, 52.38%, 936,457, 2.94
# spirit-breaker, Bull Rush, 50.88%, 910,172, 3.44
# juggernaut, Bladestorm, 54.41%, 861,162, 2.88
# zeus, Divine Rampage, 52.59%, 794,579, 4.50
# sniper, Ghillie Suit, 49.65%, 733,185, 3.21
# drow-ranger, Vantage Point, 54.49%, 672,153, 2.75
# lion, Essence Eater, 47.53%, 647,543, 2.48
# jakiro, Liquid Fire, 52.31%, 600,336, 2.73
# zeus, Livewire, 51.89%, 586,346, 4.27
# legion-commander, Stonehall Plate, 51.29%, 582,040, 3.02
# wraith-king, Spectral Blade, 61.10%, 577,950, 3.88
# silencer, Irrepressible, 58.20%, 562,442, 2.73
# warlock, Champion of Gorroth, 58.37%, 556,424, 3.36
# weaver, Skitterstep, 51.32%, 555,041, 3.38
# axe, Call Out, 55.85%, 543,582, 2.77
# nyx-assassin, Mana Burn, 48.57%, 542,520, 2.80
# crystal-maiden, Frozen Expanse, 51.77%, 535,862, 2.77
# phantom-assassin, Veiled One, 50.60%, 525,710, 2.66
# lina, Slow Burn, 44.74%, 509,285, 2.48
# ancient-apparition, Bone Chill, 53.32%, 500,956, 3.06
# viper, Poison Burst, 48.96%, 489,509, 2.64
# windranger, Tailwind, 49.64%, 479,166, 3.39
# witch-doctor, Headhunter, 54.50%, 476,707, 3.11
# dark-willow, Throwing Shade, 47.47%, 469,604, 2.87
# shadow-shaman, Cluster Cluck, 56.55%, 460,155, 3.19
# faceless-void, Temporal Impunity, 51.25%, 458,736, 3.04
# necrophos, Profane Potency, 54.95%, 455,656, 3.20
# lion, Fist of Death, 44.46%, 453,525, 2.32
# hoodwink, Go Nuts, 47.37%, 451,351, 3.26
# clinkz, Suppressive Fire, 50.93%, 448,567, 2.79
# bounty-hunter, Cutpurse, 50.05%, 447,695, 2.65
# magnus, Run Through, 41.72%, 440,353, 2.46
# rubick, Arcane Accumulation, 48.89%, 439,444, 3.41
# venomancer, Patient Zero, 52.84%, 438,689, 2.89
# monkey-king, Wukong's Faithful, 47.04%, 438,670, 2.47
# pudge, Flayer's Hook, 47.64%, 437,490, 2.58
# invoker, Elitist, 46.39%, 434,702, 3.15
# ursa, Grudge Bearer, 50.90%, 427,535, 2.72
# vengeful-spirit, Soul Strike, 52.46%, 414,602, 2.50
# riki, Contract Killer, 50.97%, 395,983, 3.12
# axe, One Man Army, 58.90%, 394,513, 3.05
# lifestealer, Corpse Eater, 50.95%, 389,060, 2.91
# earthshaker, Tectonic Buildup, 48.24%, 386,261, 2.75
# slark, Leeching Leash, 47.74%, 379,315, 2.48
# marci, Sidekick, 45.14%, 377,533, 2.31
# rubick, Frugal Filch, 44.79%, 374,518, 3.05
# earthshaker, Slugger, 45.42%, 374,024, 2.61
# bounty-hunter, Through and Through, 49.68%, 373,845, 2.76
# phantom-assassin, Methodical, 46.09%, 373,545, 2.33
# queen-of-pain, Succubus, 46.17%, 370,240, 3.06
# bristleback, Berserk, 52.92%, 362,159, 2.71
# undying, Rotting Mitts, 53.35%, 361,500, 3.02
# disruptor, Thunderstorm, 48.82%, 361,457, 3.29
# dazzle, Poison Bloom, 48.01%, 357,094, 2.54
# chaos-knight, Phantasmagoria, 55.61%, 356,515, 2.89
# techies, Spoon's Stash, 43.00%, 356,499, 2.31
# natures-prophet, Soothing Saplings, 43.76%, 354,179, 2.26
# vengeful-spirit, Avenging Missile, 52.79%, 354,176, 2.53
# hoodwink, Treebounce Trickshot, 49.69%, 344,143, 3.39
# sand-king, Sandshroud, 54.38%, 336,828, 2.76
# ogre-magi, Learning Curve, 52.35%, 331,203, 3.05
# lich, Frostbound, 57.77%, 326,776, 3.01
# windranger, Whirlwind, 48.00%, 322,071, 2.95
# skywrath-mage, Shield of the Scion, 52.51%, 321,499, 3.46
# invoker, Agnostic, 43.83%, 321,471, 2.86
# bloodseeker, Arterial Spray, 46.66%, 321,378, 2.39
# shadow-shaman, Massive Serpent Ward, 53.75%, 318,622, 2.72
# storm-spirit, Shock Collar, 50.62%, 315,300, 3.21
# slardar, Leg Day, 52.10%, 311,628, 2.72
# io, Kritzkrieg, 49.02%, 310,390, 2.83
# slardar, Brineguard, 53.15%, 308,501, 2.71
# sniper, Scattershot, 45.20%, 301,468, 2.88
# anti-mage, Mana Thirst, 50.67%, 299,667, 2.89
# keeper-of-the-light, Solar Bind, 43.37%, 296,615, 2.89
# silencer, Reverberating Silence, 58.92%, 293,289, 2.91
# enchantress, Spellbound, 47.93%, 291,116, 2.82
# lina, Thermal Runaway, 46.04%, 285,247, 2.43
# tiny, Insurmountable, 51.52%, 280,581, 3.39
# phantom-lancer, Divergence, 54.98%, 273,255, 3.25
# void-spirit, Sanctuary, 53.14%, 271,435, 3.64
# witch-doctor, Cleft Death, 50.83%, 270,605, 2.73
# centaur-warrunner, Counter-Strike, 53.81%, 270,315, 2.93
# leshrac, Chronoptic Nourishment, 58.37%, 266,097, 2.88
# skywrath-mage, Staff of the Scion, 52.13%, 264,247, 3.35
# snapfire, Ricochet II, 44.03%, 262,128, 2.53
# shadow-fiend, Lasting Presence, 46.29%, 260,566, 2.28
# juggernaut, Bladeform, 55.78%, 258,203, 3.08
# huskar, Bloodbath, 48.08%, 257,792, 2.06
# razor, Thunderhead, 49.39%, 256,216, 2.80
# enigma, Event Horizon, 51.54%, 249,035, 2.69
# jakiro, Liquid Frost, 50.61%, 246,652, 2.71
# luna, Lunar Orbit, 48.45%, 242,508, 2.49
# gyrocopter, Secondary Strikes, 47.58%, 241,869, 2.55
# abaddon, The Quickening, 56.51%, 241,310, 3.23
# wraith-king, Bone Guard, 58.31%, 239,628, 3.42
# drow-ranger, Sidestep, 54.12%, 238,694, 2.62
# muerta, Dance of the Dead, 50.97%, 238,477, 2.56
# tusk, Tag Team, 41.55%, 235,781, 2.34
# pugna, Siphoning Ward, 44.39%, 235,532, 2.74
# enchantress, Overprotective Wisps, 49.59%, 232,605, 2.99
# legion-commander, Spoils of War, 46.34%, 232,208, 2.47
# death-prophet, Spirit Collector, 47.02%, 232,156, 2.81
# medusa, Engorged, 55.46%, 229,711, 4.01
# luna, Moonstorm, 48.98%, 229,274, 2.55
# venomancer, Plague Carrier, 41.80%, 228,088, 2.46
# templar-assassin, Refractor, 49.60%, 227,867, 3.23
# mirana, Moonlight Shadow, 47.75%, 227,866, 3.16
# terrorblade, Condemned, 43.23%, 225,078, 2.11
# tiny, Crash Landing, 50.36%, 223,718, 3.21
# lifestealer, Unfettered, 44.13%, 220,658, 2.44
# night-stalker, Night Reign, 50.57%, 220,137, 3.11
# primal-beast, Romp n' Stomp, 50.27%, 215,883, 3.24
# troll-warlord, Insensitive, 53.00%, 215,122, 2.38
# techies, Spleen's Secret Sauce, 41.58%, 213,632, 2.11
# timbersaw, Twisted Chakram, 50.86%, 213,192, 3.15
# sand-king, Dust Devil, 51.90%, 210,294, 2.40
# ember-spirit, Double Impact, 45.51%, 206,900, 3.09
# spectre, Twist the Knife, 53.67%, 205,719, 3.85
# lycan, Spirit Wolves, 49.66%, 205,370, 2.99
# phoenix, Dying Light, 49.98%, 205,255, 3.24
# enigma, Splitting Image, 51.30%, 204,819, 2.59
# grimstroke, Inkstigate, 48.89%, 203,572, 2.99
# morphling, Ebb, 44.71%, 202,511, 2.36
# abaddon, Mephitic Shroud, 57.08%, 202,466, 3.49
# clockwerk, Expanded Armature, 55.63%, 199,844, 3.28
# underlord, Demon's Reach, 52.72%, 199,391, 2.87
# dark-willow, Thorny Thicket, 50.87%, 196,466, 3.19
# spectre, Forsaken, 49.47%, 195,871, 3.32
# mirana, Solar Flare, 44.33%, 192,233, 2.75
# winter-wyvern, Dragon Sight, 53.19%, 191,523, 2.86
# anti-mage, Magebane's Mirror, 47.82%, 191,426, 2.55
# natures-prophet, Ironwood Treant, 41.49%, 187,497, 2.02
# techies, Squee's Scope, 40.39%, 184,495, 2.19
# tidehunter, Krill Eater, 50.80%, 184,437, 2.85
# kunkka, High Tide, 44.96%, 182,630, 2.66
# dark-seer, Quick Wit, 51.97%, 181,297, 3.02
# pangolier, Double Jump, 39.08%, 181,211, 2.30
# dazzle, Nothl Boon, 49.71%, 179,458, 2.67
# gyrocopter, Afterburner, 46.95%, 179,438, 2.58
# tinker, Translocator, 43.67%, 178,999, 3.13
# mars, Blood Sport, 48.64%, 178,482, 2.81
# bane, Dream Stalker, 47.70%, 167,916, 2.81
# doom, Gluttony, 46.81%, 167,446, 2.59
# ancient-apparition, Exposure, 50.82%, 165,481, 2.93
# faceless-void, Time Zone, 45.93%, 164,450, 3.33
# storm-spirit, Static Slide, 50.10%, 163,053, 3.31
# tinker, Repair Bots, 39.67%, 162,733, 2.54
# treant-protector, Sapling, 50.23%, 161,158, 3.20
# outworld-destroyer, Obsidian Decimator, 52.07%, 160,336, 2.80
# dawnbreaker, Solar Charged, 47.98%, 157,970, 2.80
# dragon-knight, Fire Dragon, 49.36%, 155,411, 2.72
# sven, Heavy Plate, 46.30%, 154,543, 2.30
# clockwerk, Hookup, 51.18%, 151,949, 2.91
# spirit-breaker, Imbalanced, 47.17%, 151,780, 2.98
# omniknight, Omnipresent, 45.65%, 150,116, 2.24
# sven, Wrath of God, 47.44%, 150,017, 2.38
# outworld-destroyer, Overwhelming Devourer, 52.62%, 149,466, 2.96
# mars, Victory Feast, 46.19%, 147,201, 2.63
# oracle, Clairvoyant Cure, 53.86%, 146,919, 3.44
# alchemist, Seed Money, 47.74%, 144,484, 2.60
# death-prophet, Suppress, 47.51%, 143,219, 2.73
# dragon-knight, Frost Dragon, 54.79%, 139,230, 3.24
# centaur-warrunner, Horsepower, 55.52%, 139,126, 3.12
# puck, Jostling Rift, 44.22%, 138,629, 2.84
# phantom-lancer, Convergence, 51.86%, 137,226, 2.83
# tidehunter, Kraken Swell, 49.97%, 136,931, 2.92
# dragon-knight, Corrosive Dragon, 55.71%, 136,601, 3.20
# treant-protector, Primeval Power, 45.89%, 136,319, 2.71
# undying, Ripped, 53.89%, 133,716, 3.06
# riki, Exterminator, 50.37%, 132,364, 3.10
# clinkz, Engulfing Step, 50.61%, 131,847, 2.75
# razor, Dynamo, 50.99%, 131,577, 2.89
# oracle, Clairvoyant Curse, 47.59%, 127,840, 3.30
# broodmother, Feeding Frenzy, 44.59%, 127,192, 2.56
# snapfire, Full Bore, 43.32%, 126,574, 2.69
# lycan, Pack Leader, 48.17%, 126,132, 2.71
# templar-assassin, Voidblades, 45.44%, 125,312, 2.73
# lich, Growing Cold, 54.77%, 125,077, 3.02
# grimstroke, Fine Art, 48.83%, 124,773, 2.91
# omniknight, Healing Hammer, 46.96%, 123,894, 2.36
# earth-spirit, Resonance, 44.40%, 123,287, 2.57
# monkey-king, Simian Stride, 44.45%, 122,512, 2.30
# marci, Bodyguard, 44.03%, 122,229, 2.23
# dark-seer, Heart of Battle, 54.53%, 120,764, 3.45
# bristleback, Snot Rocket, 48.89%, 120,325, 2.48
# batrider, Stoked, 41.37%, 120,176, 2.54
# shadow-demon, Promulgate, 44.05%, 119,435, 2.70
# necrophos, Rapid Decay, 51.14%, 119,109, 2.97
# crystal-maiden, Cold Comfort, 49.28%, 117,320, 2.49
# alchemist, Mixologist, 48.66%, 117,123, 2.77
# muerta, Ofrenda, 48.12%, 116,072, 2.24
# underlord, Abyssal Horde, 57.72%, 115,231, 3.32
# meepo, More Meepo, 48.51%, 115,084, 2.40
# winter-wyvern, Essence of the Blueheart, 48.71%, 113,668, 2.54
# weaver, Hivemind, 47.98%, 112,257, 3.03
# viper, Caustic Bath, 49.35%, 109,511, 2.63
# elder-titan, Deconstruction, 48.47%, 109,137, 2.40
# night-stalker, Blinding Void, 50.10%, 105,696, 2.80
# ursa, Bear Down, 53.74%, 105,175, 3.00
# arc-warden, Disorder, 49.94%, 102,326, 2.81
# queen-of-pain, Masochist, 43.55%, 98,795, 2.68
# pugna, Rewards of Ruin, 43.34%, 98,266, 2.51
# broodmother, Necrotic Webs, 43.51%, 96,428, 2.48
# nyx-assassin, Scuttle, 47.48%, 95,743, 2.87
# timbersaw, Shredder, 49.48%, 95,609, 3.04
# naga-siren, Rip Tide, 49.84%, 94,914, 2.68
# puck, Curveball, 42.92%, 94,773, 2.62
# arc-warden, Order, 44.49%, 92,521, 2.34
# tusk, Drinking Buddies, 39.49%, 92,001, 2.27
# bane, Sleepwalk, 48.72%, 91,563, 2.98
# dawnbreaker, Gleaming Hammer, 48.48%, 91,559, 2.76
# io, Medigun, 52.09%, 89,055, 3.03
# phoenix, Hotspot, 48.45%, 88,365, 3.10
# shadow-demon, Shadow Servant, 46.41%, 85,904, 2.80
# chaos-knight, Irrationality, 53.80%, 84,792, 2.82
# void-spirit, Symmetry, 51.36%, 83,645, 3.36
# bloodseeker, Bloodrush, 45.75%, 72,910, 4.04
# brewmaster, Roll Out the Barrel, 46.97%, 72,088, 2.73
# disruptor, Kinetic Fence, 42.80%, 71,771, 2.72
# lone-druid, Bear with Me, 40.71%, 67,848, 2.27
# visage, Sepulchre, 46.67%, 66,206, 2.68
# troll-warlord, Bad Influence, 50.32%, 62,917, 2.24
# slark, Dark Reef Renegade, 43.79%, 61,858, 2.33
# leshrac, Misanthropy, 57.89%, 59,746, 2.98
# beastmaster, Beast Mode, 40.67%, 59,330, 2.18
# ember-spirit, Chain Gang, 45.56%, 55,636, 3.06
# primal-beast, Ferocity, 52.59%, 52,593, 3.13
# huskar, Nothl Transfusion, 47.57%, 51,726, 1.94
# meepo, Pack Rat, 44.58%, 49,988, 2.24
# warlock, Black Grimoire, 54.16%, 49,542, 3.14
# beastmaster, Wild Hunt, 42.36%, 44,827, 2.21
# pangolier, Thunderbolt, 43.94%, 44,370, 2.68
# visage, Faithful Followers, 42.36%, 39,429, 2.40
# morphling, Flow, 38.89%, 39,098, 2.16
# batrider, Arsonist, 38.56%, 37,114, 2.17
# terrorblade, Soul Fragment, 42.61%, 35,324, 1.93
# witch-doctor, Voodoo Festeration, 45.60%, 34,847, 2.33
# kunkka, Grog Blossom, 48.68%, 33,892, 2.90
# earth-spirit, Stepping Stone, 39.52%, 31,691, 2.18
# elder-titan, Momentum, 47.95%, 31,265, 2.39
# magnus, Reverse Reverse Polarity, 37.81%, 27,916, 2.33
# doom, Devil's Bargain, 43.02%, 27,092, 2.45
# keeper-of-the-light, Recall, 39.30%, 24,363, 2.61
# lone-druid, Unbearable, 33.36%, 24,001, 1.90
# chen, Centaur Convert, 39.44%, 23,836, 2.13
# medusa, Mana Pact, 51.10%, 20,062, 3.26
# naga-siren, Deluge, 39.82%, 19,520, 2.03
# chen, Wolf Convert, 41.38%, 16,706, 2.22
# brewmaster, Drunken Master, 46.41%, 14,635, 2.66
# chen, Troll Convert, 39.32%, 13,490, 2.07
# chen, Hellbear Convert, 40.83%, 7,702, 2.16
# chen, Satyr Convert, 40.73%, 6,216, 2.20
